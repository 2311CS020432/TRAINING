# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Example DataFrame
np.random.seed(42)
df = pd.DataFrame(np.random.randn(10, 5), columns=list('ABCDE'))

# Heatmap of absolute correlations greater than 0.5
plt.figure(figsize=(8, 6))
sns.heatmap((np.abs(df.corr()) > 0.5).astype(int), cmap='Purples', annot=True, cbar=False)
plt.title("Correlation Heatmap (Threshold: 0.5)")
plt.show()

# %%
import matplotlib.pyplot as plt
sns.heatmap(np.abs(df.corr())>0.5,cmap='Greens')
plt.show()

# %%
df.describe()
# Out:
#                A          B          C          D          E
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   -0.099048   0.035749   0.138287  -0.613652  -0.588705
# std     0.803521   0.990783   0.822706   0.985547   0.957109
# min    -1.220844  -1.150994  -1.959670  -1.913280  -1.763040
# 25%    -0.591852  -0.464457   0.006759  -1.260567  -1.461967
# 50%    -0.348777  -0.182020   0.278105  -0.754331  -0.418038
# 75%     0.400266   0.199490   0.579691  -0.343196   0.089108
# max     1.465649   1.852278   1.057122   1.523030   0.822545

# %% [raw]
# scaling techniques
# 1) standardization ---> mean 0 and std of 1
# 2) Normalization ---> range of 0 to 1 inclusive

# %%
df.describe()
# Out:
#                A          B          C          D          E
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   -0.099048   0.035749   0.138287  -0.613652  -0.588705
# std     0.803521   0.990783   0.822706   0.985547   0.957109
# min    -1.220844  -1.150994  -1.959670  -1.913280  -1.763040
# 25%    -0.591852  -0.464457   0.006759  -1.260567  -1.461967
# 50%    -0.348777  -0.182020   0.278105  -0.754331  -0.418038
# 75%     0.400266   0.199490   0.579691  -0.343196   0.089108
# max     1.465649   1.852278   1.057122   1.523030   0.822545

# %%
from sklearn.preprocessing import StandardScaler
std_scaler=StandardScaler()

# %%
scale_array=std_scaler.fit_transform(df)

# %%
scale_array.shape
# Out:
# (10, 5)

# %%
scale_df=pd.DataFrame(scale_array,columns=df.columns)
scale_df
# Out:
#           A         B         C         D         E
# 0  0.781547 -0.185132  0.652672  2.285289  0.390478
# 1 -0.177215  1.642089  0.806097  0.154205  1.245895
# 2 -0.477995 -0.533522  0.132835 -1.390018 -1.251345
# 3 -0.607697 -1.115583  0.225450 -0.314846 -0.907054
# 4  2.052636 -0.278236 -0.090659 -0.867508  0.048813
# 5  0.275449 -1.262574  0.304184  0.013918  0.327107
# 6 -0.659408  1.932603 -0.194473 -0.474944  1.554251
# 7 -1.471618  0.184176 -2.688009 -0.764230  0.865167
# 8  1.098688  0.144285 -0.325354  0.334286 -0.979982
# 9 -0.814386 -0.528106  1.177259  1.023849 -1.293330

# %%
scale_df.describe()
# Out:
#                   A             B             C             D             E
# count  1.000000e+01  1.000000e+01  1.000000e+01  1.000000e+01  1.000000e+01
# mean   3.330669e-17 -1.110223e-17  2.220446e-17  2.220446e-17 -4.440892e-17
# std    1.054093e+00  1.054093e+00  1.054093e+00  1.054093e+00  1.054093e+00
# min   -1.471618e+00 -1.262574e+00 -2.688009e+00 -1.390018e+00 -1.293330e+00
# 25%   -6.464803e-01 -5.321684e-01 -1.685197e-01 -6.919087e-01 -9.617500e-01
# 50%   -3.276049e-01 -2.316844e-01  1.791423e-01 -1.504639e-01  1.879601e-01
# 75%    6.550222e-01  1.742037e-01  5.655498e-01  2.892657e-01  7.464948e-01
# max    2.052636e+00  1.932603e+00  1.177259e+00  2.285289e+00  1.554251e+00
